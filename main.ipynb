# %% [markdown]
# # Regional Risk Predictor.
#
# A Python based program designed to calculate the risk and safety of a regions upon user input.
# Presently, the calculations are done based on regional crime indexes hardcore coded into the system.

# %% [markdown]
# ### Version Control (git)

# %%
# ! git init
# Out:
# Initialized empty Git repository in C:/Users/GLC/Documents/DevDebugg/Risk Predictor/.git/

# %%
! git add .
! git commit -m "Implemented multiple region input and calculation using list. "
! git branch -M main
# ! git remote add origin "https://github.com/King-Wealth247/Python-Regional-Risk-Calculator.git"
# Out:
# warning: in the working copy of 'main.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main 06deed8] Implemented multiple region input and calculation using list.
#  1 file changed, 95 insertions(+), 37 deletions(-)

# %%
regions = dict(        # Making use of a dictonary (Key=>value pairs). Could also use {}. data = {"Key" : "Value", "Key" : "Value"}
    far_north=67, 
    north=46, 
    adamawa=60, 
    west=69, 
    north_west=83, 
    south_west=71, 
    littoral=75, 
    center=77, 
    south=33, 
    east=47
)

# Color codes
GREEN = "\033[32m"
YELLOW = "\033[33m"
RED = "\033[31m"
BLUE = "\033[34m"
RESET = "\033[0m"   # Terminal default color

# %%
# user input.
li_location = []

print("Enter 5 reions in Cameroon: \n")

for i in range(1, 6):
    
    while True:
        location = input(f"Enter the region number {BLUE} {i} {RESET} (It must be one of the 10 regions in Cameroon): ")
        location=location.lower().replace(" ","_")      #clean texxt
        if location in regions:
            #print(location)
            li_location.append(location)
            break;
        print(f"\n{RED}It seems the region you entered isn't one of the 10 in Cameroon!{RESET} Please, reENTER\n")

# print(li_location)
# Out:
# Enter 5 reions in Cameroon:
# Enter the region number  1  (It must be one of the 10 regions in Cameroon):  north west
# Enter the region number  2  (It must be one of the 10 regions in Cameroon):  south
# Enter the region number  3  (It must be one of the 10 regions in Cameroon):  littoral
# Enter the region number  4  (It must be one of the 10 regions in Cameroon):  adamawa
# Enter the region number  5  (It must be one of the 10 regions in Cameroon):  east

# %%
# Risk Calculation Logic
#tp_result = ()    # Tuple where we'll store our results 
li_result = []     # List where we'll store our results

for location in li_location:  
    if regions[location] >= 70:
        risk = "high"
        COLOR = RED
    elif regions[location] >= 40:
        risk = "moderate"
        COLOR = YELLOW
    else:
        risk = "low"
        COLOR = GREEN
    
    #tp_result += ({"location" : location, "risk" : risk, "color" : COLOR}, ) # Concatenate dictionary containig results as a tuple to the result tuple
    li_result.append([location, risk, COLOR])

# print(li_result)
# Out:
# 5
# moderate
# [['north_west', 'high', '\x1b'], ['south', 'low', '\x1b'], ['littoral', 'high', '\x1b'], ['adamawa', 'moderate', '\x1b'], ['east', 'moderate', '\x1b']]

# %%
# Calculated Output
for i in range(len(li_result)):
    print(f"\nLocation: {li_result[i][0].replace("_", " ").title()} \nSecurity Risk: {li_result[i][2]}{li_result[i][1]}{RESET}\n")
# print(f"\nYour Destination: {location.replace("_", " ").title()} \nRisk Level: {COLOR}{risk.title()}{RESET}")
# Out:
# Location: North West
# Security Risk: high
#
#
# Location: South
# Security Risk: low
#
#
# Location: Littoral
# Security Risk: high
#
#
# Location: Adamawa
# Security Risk: moderate
#
#
# Location: East
# Security Risk: moderate

# %%
# Push to github
! git push -u origin main
# Out:
# branch 'main' set up to track 'origin/main'.
# To https://github.com/King-Wealth247/Python-Regional-Risk-Calculator.git
#    ac7519d..06deed8  main -> main
